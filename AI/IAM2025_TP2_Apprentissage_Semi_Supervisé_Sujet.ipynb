# %% [markdown]
# # Apprentissage Semi-Supervisé
#
# On se propose dans ce TP d'illustrer certaines techniques d'apprentissage semi-supervisé vues en cours.
#
# Dans tout ce qui suit, on considère que l'on dispose d'un ensemble de données $x_{lab}$ labellisées et d'un ensemble de donnés $x_{unlab}$ non labellisées.

# %% [markdown]
# ## Datasets

# %% [markdown]
# Commencez par exécuter ces codes qui vos permettront de charger les datasets que nous allons utiliser et de les séparer en données labellisées et non labellisées, ainsi qu'en données de test.

# %% [markdown]
# ### Dataset des deux clusters

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import datasets
import matplotlib.pyplot as plt

def generate_2clusters_dataset(num_lab = 10, num_unlab=740, num_test=250):
  num_samples = num_lab + num_unlab + num_test
  # Génération de 1000 données du dataset des 2 lunes
  x, y = datasets.make_blobs(n_samples=[round(num_samples/2), round(num_samples/2)], n_features=2, center_box=(- 3, 3), random_state=1)

  x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=num_test/num_samples, random_state=1)
  x_train_lab, x_train_unlab, y_train_lab, y_train_unlab = train_test_split(x_train, y_train, test_size=num_unlab/(num_unlab+num_lab), random_state=6)

  return x_train_lab, y_train_lab, x_train_unlab, y_train_unlab, x_test, y_test

# %%
x_train_lab, y_train_lab, x_train_unlab, y_train_unlab, x_test, y_test = generate_2clusters_dataset(num_lab = 10, num_unlab=740, num_test=250)

print(x_train_lab.shape, x_train_unlab.shape, x_test.shape)
print(y_train_lab.shape, y_train_unlab.shape, y_test.shape)

# Affichage des données
plt.plot(x_train_unlab[y_train_unlab==0,0], x_train_unlab[y_train_unlab==0,1], color=(0.5,0.5,0.5), marker='.', linestyle=' ')
plt.plot(x_train_unlab[y_train_unlab==1,0], x_train_unlab[y_train_unlab==1,1], color=(0.5,0.5,0.5), marker='.', linestyle=' ')

plt.plot(x_test[y_test==0,0], x_test[y_test==0,1], 'b+')
plt.plot(x_test[y_test==1,0], x_test[y_test==1,1], 'r+')

plt.plot(x_train_lab[y_train_lab==0,0], x_train_lab[y_train_lab==0,1], 'b.', markersize=30)
plt.plot(x_train_lab[y_train_lab==1,0], x_train_lab[y_train_lab==1,1], 'r.', markersize=30)

plt.show()
# Out:
# (10, 2) (740, 2) (250, 2)
# (10,) (740,) (250,)

# %% [markdown]
# ### Dataset des 2 lunes

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1xb_gasBJ6sEmbyvCWTnVEAsbspyDCyFL">
# <caption><center> Figure 1: Comparaison de différents algorithmes semi-supervisés sur le dataset des 2 lunes</center></caption>

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import datasets
import matplotlib.pyplot as plt

def generate_2moons_dataset(num_lab = 10, num_unlab=740, num_test=250):
  num_samples = num_lab + num_unlab + num_test
  # Génération de 1000 données du dataset des 2 lunes
  x, y = datasets.make_moons(n_samples=num_samples, noise=0.1, random_state=1)

  x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=num_test/num_samples, random_state=1)
  x_train_lab, x_train_unlab, y_train_lab, y_train_unlab = train_test_split(x_train, y_train, test_size=num_unlab/(num_unlab+num_lab), random_state=6)

  return x_train_lab, y_train_lab, x_train_unlab, y_train_unlab, x_test, y_test

# %%
x_train_lab, y_train_lab, x_train_unlab, y_train_unlab, x_test, y_test = generate_2moons_dataset(num_lab = 10, num_unlab=740, num_test=250)

print(x_train_lab.shape, x_train_unlab.shape, x_test.shape)
print(y_train_lab.shape, y_train_unlab.shape, y_test.shape)

# Affichage des données
plt.plot(x_train_unlab[y_train_unlab==0,0], x_train_unlab[y_train_unlab==0,1], 'b.')
plt.plot(x_train_unlab[y_train_unlab==1,0], x_train_unlab[y_train_unlab==1,1], 'r.')

plt.plot(x_test[y_test==0,0], x_test[y_test==0,1], 'b+')
plt.plot(x_test[y_test==1,0], x_test[y_test==1,1], 'r+')

plt.plot(x_train_lab[y_train_lab==0,0], x_train_lab[y_train_lab==0,1], 'b.', markersize=30)
plt.plot(x_train_lab[y_train_lab==1,0], x_train_lab[y_train_lab==1,1], 'r.', markersize=30)

plt.show()
# Out:
# (10, 2) (740, 2) (250, 2)
# (10,) (740,) (250,)

# %% [markdown]
# ## Modèles

# %% [markdown]
# Nous allons dès maintenant préparer les modèles que nous utiliserons dans la suite.
#
# **Travail à faire** Complétez les modèles ci-dessous :

# %% [markdown]
# Pour le dataset des 2 clusters, un simple perceptron monocouche suffira :

# %%
from tensorflow.keras.layers import *
from tensorflow.keras import Model, Input
# A COMPLETER
# Ici, écrire un simple perceptron monocouche
def create_model_2clusters():

  inputs = Input(shape=(2,))
  outputs = Dense(1, activation="sigmoid")(inputs)

  model = Model(inputs=inputs, outputs=outputs)

  return model

# %% [markdown]
# Pour le dataset des 2 lunes, implémentez un perceptron multi-couches à une couche cachée, par exemple de 20 neurones.

# %%
# A COMPLETER
# Ici, écrire un perceptron multi-couches à une seule couche cachée comprenant 20 neurones
def create_model_2moons():

  inputs = keras.Input(shape=(2,))

  layer = Dense(20, activation="relu")(inputs)

  outputs = Dense(1, activation="sigmoid")(layer)
  model = keras.Model(inputs=inputs, outputs=outputs)

  return model

# %% [markdown]
# ## Apprentissage supervisé

# %% [markdown]
# Commencez par bien lire le code ci-dessous, qui vous permet de mettre en place un apprentissage supervisé en détaillant la boucle d'apprentissage (de l'algorithme de descente de gradient stochastique). Cela nous permettra d'avoir plus de contrôle dans la suite pour implémenter les algorithmes semi-supervisés. Cela vous fournira également une base contre laquelle comparer les algorithmes semi-supervisés.
#
# En quelques mots, l'algorithme est organisé autour d'une double boucle : une sur les *epochs*, et la 2nde sur les *mini-batches*.
#
# Pour chaque nouveau batch de données, on réalise la succession d'étapes suivantes dans un bloc **GradientTape** qui permet le calcul automatique des gradients :
#
#
# 1.   Prédiction de la sortie du modèle sur les données du batch
# 2.   Calcul de la fonction de perte entre sortie du réseau et labels réels associés aux élements du batch
# 3.   Calcul des gradients de la perte par rapport aux paramètres du réseau (par différentiation automatique)
# 4.   Mise à jour des paramètres grâce aux gradients calculés.

# %% [markdown]
# ### Dataset des 2 clusters

# %%
import tensorflow as tf
from tensorflow import keras
import math

# Données et modèle du problème des 2 clusters
x_train_lab, y_train_lab, x_train_unlab, y_train_unlab, x_test, y_test = generate_2clusters_dataset(num_lab = 10, num_unlab=740, num_test=250)
model = create_model_2clusters()

# Hyperparamètres de l'apprentissage
epochs = 150
batch_size = 16
if batch_size < x_train_lab.shape[0]:
  steps_per_epoch = math.floor(x_train_lab.shape[0]/batch_size)
else:
  steps_per_epoch = 1
  batch_size = x_train_lab.shape[0]

# Instanciation d'un optimiseur et d'une fonction de coût.
optimizer = keras.optimizers.Adam(learning_rate=1e-2)
loss_fn = keras.losses.BinaryCrossentropy()

# Préparation des métriques pour le suivi de la performance du modèle.
train_acc_metric = keras.metrics.BinaryAccuracy()
test_acc_metric = keras.metrics.BinaryAccuracy()

# Indices de l'ensemble labellisé
indices = np.arange(x_train_lab.shape[0])

# Boucle sur les epochs
for epoch in range(epochs):

  # A chaque nouvelle epoch, on randomise les indices de l'ensemble labellisé
  np.random.shuffle(indices)

  # Et on recommence à cumuler la loss
  cum_loss_value = 0

  for step in range(steps_per_epoch):

    # Sélection des données du prochain batch
    x_batch = x_train_lab[indices[step*batch_size: (step+1)*batch_size]]
    y_batch = y_train_lab[indices[step*batch_size: (step+1)*batch_size]]

    # Etape nécessaire pour comparer y_batch à la sortie du réseau
    y_batch = np.expand_dims(y_batch, 1)

    # Les opérations effectuées par le modèle dans ce bloc sont suivies et permettront
    # la différentiation automatique.
    with tf.GradientTape() as tape:

      # Application du réseau aux données d'entrée
      y_pred = model(x_batch, training=True)  # Logits for this minibatch

      # Calcul de la fonction de perte sur ce batch
      loss_value = loss_fn(y_batch, y_pred)

      # Calcul des gradients par différentiation automatique
      grads = tape.gradient(loss_value, model.trainable_weights)

      # Réalisation d'une itération de la descente de gradient (mise à jour des paramètres du réseau)
      optimizer.apply_gradients(zip(grads, model.trainable_weights))

      # Mise à jour de la métrique
      train_acc_metric.update_state(y_batch, y_pred)

      cum_loss_value = cum_loss_value + loss_value

  # Calcul de la précision à la fin de l'epoch
  train_acc = train_acc_metric.result()

  # Calcul de la précision sur l'ensemble de test à la fin de l'epoch
  test_logits = model(x_test, training=False)
  test_acc_metric.update_state(np.expand_dims(y_test, 1), test_logits)
  test_acc = test_acc_metric.result()

  print("Epoch %4d : Loss : %.4f, Acc : %.4f, Test Acc : %.4f" % (epoch, float(cum_loss_value/steps_per_epoch), float(train_acc), float(test_acc)))

  # Remise à zéro des métriques pour la prochaine epoch
  train_acc_metric.reset_state()
  test_acc_metric.reset_state()
# Out:
# Epoch    0 : Loss : 2.9400, Acc : 0.1000, Test Acc : 0.0440
# Epoch    1 : Loss : 2.9121, Acc : 0.1000, Test Acc : 0.0440
# Epoch    2 : Loss : 2.8843, Acc : 0.1000, Test Acc : 0.0440
# Epoch    3 : Loss : 2.8565, Acc : 0.1000, Test Acc : 0.0440
# Epoch    4 : Loss : 2.8288, Acc : 0.1000, Test Acc : 0.0440
# Epoch    5 : Loss : 2.8012, Acc : 0.1000, Test Acc : 0.0440
# Epoch    6 : Loss : 2.7736, Acc : 0.0000, Test Acc : 0.0440
# Epoch    7 : Loss : 2.7461, Acc : 0.0000, Test Acc : 0.0440
# Epoch    8 : Loss : 2.7186, Acc : 0.0000, Test Acc : 0.0440
# Epoch    9 : Loss : 2.6912, Acc : 0.0000, Test Acc : 0.0400
# Epoch   10 : Loss : 2.6639, Acc : 0.0000, Test Acc : 0.0400
# Epoch   11 : Loss : 2.6366, Acc : 0.0000, Test Acc : 0.0440
# Epoch   12 : Loss : 2.6094, Acc : 0.0000, Test Acc : 0.0440
# Epoch   13 : Loss : 2.5823, Acc : 0.0000, Test Acc : 0.0440
# Epoch   14 : Loss : 2.5553, Acc : 0.0000, Test Acc : 0.0440
# Epoch   15 : Loss : 2.5284, Acc : 0.0000, Test Acc : 0.0440
# Epoch   16 : Loss : 2.5015, Acc : 0.0000, Test Acc : 0.0480
# Epoch   17 : Loss : 2.4748, Acc : 0.0000, Test Acc : 0.0480
# Epoch   18 : Loss : 2.4481, Acc : 0.0000, Test Acc : 0.0480
# Epoch   19 : Loss : 2.4216, Acc : 0.0000, Test Acc : 0.0480
# Epoch   20 : Loss : 2.3951, Acc : 0.0000, Test Acc : 0.0480
# Epoch   21 : Loss : 2.3688, Acc : 0.0000, Test Acc : 0.0480
# Epoch   22 : Loss : 2.3425, Acc : 0.0000, Test Acc : 0.0480
# Epoch   23 : Loss : 2.3164, Acc : 0.0000, Test Acc : 0.0480
# Epoch   24 : Loss : 2.2904, Acc : 0.0000, Test Acc : 0.0440
# Epoch   25 : Loss : 2.2646, Acc : 0.0000, Test Acc : 0.0440
# Epoch   26 : Loss : 2.2388, Acc : 0.0000, Test Acc : 0.0440
# Epoch   27 : Loss : 2.2132, Acc : 0.0000, Test Acc : 0.0440
# Epoch   28 : Loss : 2.1877, Acc : 0.0000, Test Acc : 0.0440
# Epoch   29 : Loss : 2.1623, Acc : 0.0000, Test Acc : 0.0440
# Epoch   30 : Loss : 2.1371, Acc : 0.0000, Test Acc : 0.0440
# Epoch   31 : Loss : 2.1120, Acc : 0.0000, Test Acc : 0.0400
# Epoch   32 : Loss : 2.0871, Acc : 0.0000, Test Acc : 0.0400
# Epoch   33 : Loss : 2.0623, Acc : 0.0000, Test Acc : 0.0400
# Epoch   34 : Loss : 2.0377, Acc : 0.0000, Test Acc : 0.0440
# Epoch   35 : Loss : 2.0132, Acc : 0.0000, Test Acc : 0.0440
# Epoch   36 : Loss : 1.9888, Acc : 0.0000, Test Acc : 0.0440
# Epoch   37 : Loss : 1.9646, Acc : 0.0000, Test Acc : 0.0440
# Epoch   38 : Loss : 1.9406, Acc : 0.0000, Test Acc : 0.0480
# Epoch   39 : Loss : 1.9167, Acc : 0.0000, Test Acc : 0.0480
# Epoch   40 : Loss : 1.8930, Acc : 0.0000, Test Acc : 0.0480
# Epoch   41 : Loss : 1.8694, Acc : 0.0000, Test Acc : 0.0480
# Epoch   42 : Loss : 1.8460, Acc : 0.0000, Test Acc : 0.0520
# Epoch   43 : Loss : 1.8227, Acc : 0.0000, Test Acc : 0.0520
# Epoch   44 : Loss : 1.7996, Acc : 0.0000, Test Acc : 0.0520
# Epoch   45 : Loss : 1.7767, Acc : 0.0000, Test Acc : 0.0560
# Epoch   46 : Loss : 1.7539, Acc : 0.0000, Test Acc : 0.0600
# Epoch   47 : Loss : 1.7312, Acc : 0.0000, Test Acc : 0.0600
# Epoch   48 : Loss : 1.7087, Acc : 0.0000, Test Acc : 0.0600
# Epoch   49 : Loss : 1.6864, Acc : 0.0000, Test Acc : 0.0600
# Epoch   50 : Loss : 1.6642, Acc : 0.0000, Test Acc : 0.0600
# Epoch   51 : Loss : 1.6422, Acc : 0.0000, Test Acc : 0.0600
# Epoch   52 : Loss : 1.6204, Acc : 0.0000, Test Acc : 0.0600
# Epoch   53 : Loss : 1.5987, Acc : 0.0000, Test Acc : 0.0640
# Epoch   54 : Loss : 1.5772, Acc : 0.0000, Test Acc : 0.0640
# Epoch   55 : Loss : 1.5558, Acc : 0.0000, Test Acc : 0.0640
# Epoch   56 : Loss : 1.5346, Acc : 0.0000, Test Acc : 0.0640
# Epoch   57 : Loss : 1.5135, Acc : 0.0000, Test Acc : 0.0640
# Epoch   58 : Loss : 1.4927, Acc : 0.0000, Test Acc : 0.0600
# Epoch   59 : Loss : 1.4720, Acc : 0.0000, Test Acc : 0.0600
# Epoch   60 : Loss : 1.4514, Acc : 0.0000, Test Acc : 0.0600
# Epoch   61 : Loss : 1.4311, Acc : 0.0000, Test Acc : 0.0600
# Epoch   62 : Loss : 1.4109, Acc : 0.0000, Test Acc : 0.0640
# Epoch   63 : Loss : 1.3909, Acc : 0.0000, Test Acc : 0.0640
# Epoch   64 : Loss : 1.3711, Acc : 0.0000, Test Acc : 0.0680
# Epoch   65 : Loss : 1.3514, Acc : 0.0000, Test Acc : 0.0720
# Epoch   66 : Loss : 1.3320, Acc : 0.0000, Test Acc : 0.0720
# Epoch   67 : Loss : 1.3127, Acc : 0.0000, Test Acc : 0.0720
# Epoch   68 : Loss : 1.2936, Acc : 0.0000, Test Acc : 0.0720
# Epoch   69 : Loss : 1.2747, Acc : 0.0000, Test Acc : 0.0720
# Epoch   70 : Loss : 1.2561, Acc : 0.0000, Test Acc : 0.0760
# Epoch   71 : Loss : 1.2376, Acc : 0.0000, Test Acc : 0.0760
# Epoch   72 : Loss : 1.2193, Acc : 0.1000, Test Acc : 0.0800
# Epoch   73 : Loss : 1.2012, Acc : 0.1000, Test Acc : 0.0800
# Epoch   74 : Loss : 1.1833, Acc : 0.1000, Test Acc : 0.0800
# Epoch   75 : Loss : 1.1656, Acc : 0.1000, Test Acc : 0.0800
# Epoch   76 : Loss : 1.1482, Acc : 0.1000, Test Acc : 0.0800
# Epoch   77 : Loss : 1.1309, Acc : 0.1000, Test Acc : 0.0840
# Epoch   78 : Loss : 1.1139, Acc : 0.1000, Test Acc : 0.0880
# Epoch   79 : Loss : 1.0970, Acc : 0.1000, Test Acc : 0.0880
# Epoch   80 : Loss : 1.0804, Acc : 0.1000, Test Acc : 0.0920
# Epoch   81 : Loss : 1.0640, Acc : 0.1000, Test Acc : 0.0920
# Epoch   82 : Loss : 1.0478, Acc : 0.1000, Test Acc : 0.0960
# Epoch   83 : Loss : 1.0319, Acc : 0.1000, Test Acc : 0.0960
# Epoch   84 : Loss : 1.0161, Acc : 0.1000, Test Acc : 0.1000
# Epoch   85 : Loss : 1.0006, Acc : 0.1000, Test Acc : 0.1000
# Epoch   86 : Loss : 0.9853, Acc : 0.1000, Test Acc : 0.1040
# Epoch   87 : Loss : 0.9702, Acc : 0.2000, Test Acc : 0.1080
# Epoch   88 : Loss : 0.9553, Acc : 0.2000, Test Acc : 0.1120
# Epoch   89 : Loss : 0.9407, Acc : 0.2000, Test Acc : 0.1240
# Epoch   90 : Loss : 0.9263, Acc : 0.2000, Test Acc : 0.1400
# Epoch   91 : Loss : 0.9121, Acc : 0.2000, Test Acc : 0.1480
# Epoch   92 : Loss : 0.8981, Acc : 0.2000, Test Acc : 0.1480
# Epoch   93 : Loss : 0.8843, Acc : 0.2000, Test Acc : 0.1520
# Epoch   94 : Loss : 0.8708, Acc : 0.2000, Test Acc : 0.1680
# Epoch   95 : Loss : 0.8575, Acc : 0.2000, Test Acc : 0.1760
# Epoch   96 : Loss : 0.8444, Acc : 0.2000, Test Acc : 0.1920
# Epoch   97 : Loss : 0.8315, Acc : 0.3000, Test Acc : 0.2160
# Epoch   98 : Loss : 0.8188, Acc : 0.3000, Test Acc : 0.2280
# Epoch   99 : Loss : 0.8064, Acc : 0.4000, Test Acc : 0.2440
# Epoch  100 : Loss : 0.7942, Acc : 0.5000, Test Acc : 0.2640
# Epoch  101 : Loss : 0.7821, Acc : 0.5000, Test Acc : 0.2680
# Epoch  102 : Loss : 0.7703, Acc : 0.5000, Test Acc : 0.2800
# Epoch  103 : Loss : 0.7587, Acc : 0.5000, Test Acc : 0.3120
# Epoch  104 : Loss : 0.7473, Acc : 0.5000, Test Acc : 0.3200
# Epoch  105 : Loss : 0.7362, Acc : 0.5000, Test Acc : 0.3560
# Epoch  106 : Loss : 0.7252, Acc : 0.5000, Test Acc : 0.3800
# Epoch  107 : Loss : 0.7144, Acc : 0.5000, Test Acc : 0.3920
# Epoch  108 : Loss : 0.7038, Acc : 0.5000, Test Acc : 0.4240
# Epoch  109 : Loss : 0.6934, Acc : 0.5000, Test Acc : 0.4400
# Epoch  110 : Loss : 0.6833, Acc : 0.5000, Test Acc : 0.4760
# Epoch  111 : Loss : 0.6733, Acc : 0.5000, Test Acc : 0.4960
# Epoch  112 : Loss : 0.6635, Acc : 0.6000, Test Acc : 0.5080
# Epoch  113 : Loss : 0.6538, Acc : 0.7000, Test Acc : 0.5320
# Epoch  114 : Loss : 0.6444, Acc : 0.8000, Test Acc : 0.5720
# Epoch  115 : Loss : 0.6352, Acc : 0.8000, Test Acc : 0.5880
# Epoch  116 : Loss : 0.6261, Acc : 0.9000, Test Acc : 0.6120
# Epoch  117 : Loss : 0.6172, Acc : 0.9000, Test Acc : 0.6600
# Epoch  118 : Loss : 0.6085, Acc : 0.9000, Test Acc : 0.6680
# Epoch  119 : Loss : 0.6000, Acc : 0.9000, Test Acc : 0.6880
# Epoch  120 : Loss : 0.5916, Acc : 0.9000, Test Acc : 0.7040
# Epoch  121 : Loss : 0.5834, Acc : 0.9000, Test Acc : 0.7320
# Epoch  122 : Loss : 0.5753, Acc : 0.9000, Test Acc : 0.7440
# Epoch  123 : Loss : 0.5675, Acc : 0.9000, Test Acc : 0.7560
# Epoch  124 : Loss : 0.5597, Acc : 0.9000, Test Acc : 0.7720
# Epoch  125 : Loss : 0.5522, Acc : 0.9000, Test Acc : 0.8000
# Epoch  126 : Loss : 0.5448, Acc : 0.9000, Test Acc : 0.8040
# Epoch  127 : Loss : 0.5375, Acc : 0.9000, Test Acc : 0.8120
# Epoch  128 : Loss : 0.5304, Acc : 1.0000, Test Acc : 0.8200
# Epoch  129 : Loss : 0.5234, Acc : 1.0000, Test Acc : 0.8240
# Epoch  130 : Loss : 0.5165, Acc : 1.0000, Test Acc : 0.8320
# Epoch  131 : Loss : 0.5098, Acc : 1.0000, Test Acc : 0.8400
# Epoch  132 : Loss : 0.5033, Acc : 1.0000, Test Acc : 0.8480
# Epoch  133 : Loss : 0.4968, Acc : 1.0000, Test Acc : 0.8520
# Epoch  134 : Loss : 0.4905, Acc : 1.0000, Test Acc : 0.8520
# Epoch  135 : Loss : 0.4844, Acc : 1.0000, Test Acc : 0.8600
# Epoch  136 : Loss : 0.4783, Acc : 1.0000, Test Acc : 0.8600
# Epoch  137 : Loss : 0.4724, Acc : 1.0000, Test Acc : 0.8640
# Epoch  138 : Loss : 0.4666, Acc : 1.0000, Test Acc : 0.8720
# Epoch  139 : Loss : 0.4609, Acc : 1.0000, Test Acc : 0.8800
# Epoch  140 : Loss : 0.4553, Acc : 1.0000, Test Acc : 0.8880
# Epoch  141 : Loss : 0.4498, Acc : 1.0000, Test Acc : 0.8880
# Epoch  142 : Loss : 0.4445, Acc : 1.0000, Test Acc : 0.8920
# Epoch  143 : Loss : 0.4392, Acc : 1.0000, Test Acc : 0.8960
# Epoch  144 : Loss : 0.4341, Acc : 1.0000, Test Acc : 0.9040
# Epoch  145 : Loss : 0.4290, Acc : 1.0000, Test Acc : 0.9040
# Epoch  146 : Loss : 0.4241, Acc : 1.0000, Test Acc : 0.9080
# Epoch  147 : Loss : 0.4192, Acc : 1.0000, Test Acc : 0.9160
# Epoch  148 : Loss : 0.4145, Acc : 1.0000, Test Acc : 0.9200
# Epoch  149 : Loss : 0.4098, Acc : 1.0000, Test Acc : 0.9200

# %%
from mlxtend.plotting import plot_decision_regions

# Affichage des données
plt.plot(x_train_unlab[y_train_unlab==0,0], x_train_unlab[y_train_unlab==0,1], 'b.')
plt.plot(x_train_unlab[y_train_unlab==1,0], x_train_unlab[y_train_unlab==1,1], 'r.')

plt.plot(x_test[y_test==0,0], x_test[y_test==0,1], 'b+')
plt.plot(x_test[y_test==1,0], x_test[y_test==1,1], 'r+')

plt.plot(x_train_lab[y_train_lab==0,0], x_train_lab[y_train_lab==0,1], 'b.', markersize=30)
plt.plot(x_train_lab[y_train_lab==1,0], x_train_lab[y_train_lab==1,1], 'r.', markersize=30)

plt.show()

#Affichage de la frontière de décision
plot_decision_regions(x_train_unlab, y_train_unlab, clf=model, legend=2)
plt.show()
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 11s 1ms/step

# %% [markdown]
# ### Dataset des 2 lunes

# %% [markdown]
# **Travail à faire** : Mettez en place le même apprentissage pour le dataset des 2 lunes.

# %%
import tensorflow as tf
from tensorflow import keras
import math

# Données et modèle du problème des 2 lunes
x_train_lab, y_train_lab, x_train_unlab, y_train_unlab, x_test, y_test = generate_2moons_dataset(num_lab = 10, num_unlab=740, num_test=250)
model = create_model_2moons()

# Hyperparamètres de l'apprentissage
epochs = 150
batch_size = 16
if batch_size < x_train_lab.shape[0]:
  steps_per_epoch = math.floor(x_train_lab.shape[0]/batch_size)
else:
  steps_per_epoch = 1
  batch_size = x_train_lab.shape[0]

# Instanciation d'un optimiseur et d'une fonction de coût.
optimizer = keras.optimizers.Adam(learning_rate=1e-2)
loss_fn = keras.losses.BinaryCrossentropy()

# Préparation des métriques pour le suivi de la performance du modèle.
train_acc_metric = keras.metrics.BinaryAccuracy()
test_acc_metric = keras.metrics.BinaryAccuracy()

# Indices de l'ensemble labellisé
indices = np.arange(x_train_lab.shape[0])

# Boucle sur les epochs
for epoch in range(epochs):

  # A chaque nouvelle epoch, on randomise les indices de l'ensemble labellisé
  np.random.shuffle(indices)

  # Et on recommence à cumuler la loss
  cum_loss_value = 0

  for step in range(steps_per_epoch):

    # Sélection des données du prochain batch
    x_batch = x_train_lab[indices[step*batch_size: (step+1)*batch_size]]
    y_batch = y_train_lab[indices[step*batch_size: (step+1)*batch_size]]

    # Etape nécessaire pour comparer y_batch à la sortie du réseau
    y_batch = np.expand_dims(y_batch, 1)

    # Les opérations effectuées par le modèle dans ce bloc sont suivies et permettront
    # la différentiation automatique.
    with tf.GradientTape() as tape:

      # Application du réseau aux données d'entrée
      y_pred = model(x_batch, training=True)  # Logits for this minibatch

      # Calcul de la fonction de perte sur ce batch
      loss_value = loss_fn(y_batch, y_pred)

      # Calcul des gradients par différentiation automatique
      grads = tape.gradient(loss_value, model.trainable_weights)

      # Réalisation d'une itération de la descente de gradient (mise à jour des paramètres du réseau)
      optimizer.apply_gradients(zip(grads, model.trainable_weights))

      # Mise à jour de la métrique
      train_acc_metric.update_state(y_batch, y_pred)

      cum_loss_value = cum_loss_value + loss_value

  # Calcul de la précision à la fin de l'epoch
  train_acc = train_acc_metric.result()

  # Calcul de la précision sur l'ensemble de test à la fin de l'epoch
  test_logits = model(x_test, training=False)
  test_acc_metric.update_state(np.expand_dims(y_test, 1), test_logits)
  test_acc = test_acc_metric.result()

  print("Epoch %4d : Loss : %.4f, Acc : %.4f, Test Acc : %.4f" % (epoch, float(cum_loss_value/steps_per_epoch), float(train_acc), float(test_acc)))

  # Remise à zéro des métriques pour la prochaine epoch
  train_acc_metric.reset_state()
  test_acc_metric.reset_state()
# Out:
# Epoch    0 : Loss : 0.8720, Acc : 0.3000, Test Acc : 0.3680
# Epoch    1 : Loss : 0.8350, Acc : 0.3000, Test Acc : 0.4040
# Epoch    2 : Loss : 0.8008, Acc : 0.4000, Test Acc : 0.4720
# Epoch    3 : Loss : 0.7680, Acc : 0.5000, Test Acc : 0.5360
# Epoch    4 : Loss : 0.7370, Acc : 0.7000, Test Acc : 0.5960
# Epoch    5 : Loss : 0.7077, Acc : 0.7000, Test Acc : 0.6560
# Epoch    6 : Loss : 0.6804, Acc : 0.7000, Test Acc : 0.6800
# Epoch    7 : Loss : 0.6552, Acc : 0.7000, Test Acc : 0.7200
# Epoch    8 : Loss : 0.6324, Acc : 0.8000, Test Acc : 0.7560
# Epoch    9 : Loss : 0.6114, Acc : 0.9000, Test Acc : 0.7720
# Epoch   10 : Loss : 0.5921, Acc : 0.9000, Test Acc : 0.7840
# Epoch   11 : Loss : 0.5747, Acc : 0.9000, Test Acc : 0.7880
# Epoch   12 : Loss : 0.5586, Acc : 0.9000, Test Acc : 0.7760
# Epoch   13 : Loss : 0.5436, Acc : 0.9000, Test Acc : 0.7720
# Epoch   14 : Loss : 0.5297, Acc : 0.9000, Test Acc : 0.7600
# Epoch   15 : Loss : 0.5165, Acc : 0.9000, Test Acc : 0.7680
# Epoch   16 : Loss : 0.5043, Acc : 0.9000, Test Acc : 0.7640
# Epoch   17 : Loss : 0.4926, Acc : 0.9000, Test Acc : 0.7680
# Epoch   18 : Loss : 0.4814, Acc : 0.9000, Test Acc : 0.7800
# Epoch   19 : Loss : 0.4709, Acc : 0.9000, Test Acc : 0.7920
# Epoch   20 : Loss : 0.4608, Acc : 0.9000, Test Acc : 0.8080
# Epoch   21 : Loss : 0.4512, Acc : 0.9000, Test Acc : 0.8320
# Epoch   22 : Loss : 0.4419, Acc : 0.9000, Test Acc : 0.8360
# Epoch   23 : Loss : 0.4329, Acc : 0.9000, Test Acc : 0.8440
# Epoch   24 : Loss : 0.4243, Acc : 0.9000, Test Acc : 0.8480
# Epoch   25 : Loss : 0.4159, Acc : 0.9000, Test Acc : 0.8520
# Epoch   26 : Loss : 0.4079, Acc : 0.9000, Test Acc : 0.8480
# Epoch   27 : Loss : 0.4002, Acc : 0.9000, Test Acc : 0.8480
# Epoch   28 : Loss : 0.3927, Acc : 0.9000, Test Acc : 0.8560
# Epoch   29 : Loss : 0.3855, Acc : 0.9000, Test Acc : 0.8520
# Epoch   30 : Loss : 0.3785, Acc : 0.9000, Test Acc : 0.8560
# Epoch   31 : Loss : 0.3714, Acc : 0.9000, Test Acc : 0.8600
# Epoch   32 : Loss : 0.3645, Acc : 0.9000, Test Acc : 0.8640
# Epoch   33 : Loss : 0.3576, Acc : 0.9000, Test Acc : 0.8680
# Epoch   34 : Loss : 0.3509, Acc : 0.9000, Test Acc : 0.8720
# Epoch   35 : Loss : 0.3443, Acc : 0.9000, Test Acc : 0.8800
# Epoch   36 : Loss : 0.3378, Acc : 0.9000, Test Acc : 0.8840
# Epoch   37 : Loss : 0.3315, Acc : 0.9000, Test Acc : 0.8840
# Epoch   38 : Loss : 0.3253, Acc : 0.9000, Test Acc : 0.8800
# Epoch   39 : Loss : 0.3194, Acc : 0.9000, Test Acc : 0.8800
# Epoch   40 : Loss : 0.3137, Acc : 0.9000, Test Acc : 0.8800
# Epoch   41 : Loss : 0.3081, Acc : 0.9000, Test Acc : 0.8760
# Epoch   42 : Loss : 0.3028, Acc : 0.9000, Test Acc : 0.8800
# Epoch   43 : Loss : 0.2978, Acc : 0.9000, Test Acc : 0.8800
# Epoch   44 : Loss : 0.2930, Acc : 0.9000, Test Acc : 0.8800
# Epoch   45 : Loss : 0.2884, Acc : 0.9000, Test Acc : 0.8720
# Epoch   46 : Loss : 0.2840, Acc : 0.8000, Test Acc : 0.8640
# Epoch   47 : Loss : 0.2800, Acc : 0.8000, Test Acc : 0.8640
# Epoch   48 : Loss : 0.2762, Acc : 0.8000, Test Acc : 0.8680
# Epoch   49 : Loss : 0.2726, Acc : 0.8000, Test Acc : 0.8720
# Epoch   50 : Loss : 0.2691, Acc : 0.8000, Test Acc : 0.8760
# Epoch   51 : Loss : 0.2659, Acc : 0.8000, Test Acc : 0.8720
# Epoch   52 : Loss : 0.2628, Acc : 0.8000, Test Acc : 0.8720
# Epoch   53 : Loss : 0.2598, Acc : 0.8000, Test Acc : 0.8760
# Epoch   54 : Loss : 0.2569, Acc : 0.8000, Test Acc : 0.8800
# Epoch   55 : Loss : 0.2542, Acc : 0.8000, Test Acc : 0.8800
# Epoch   56 : Loss : 0.2515, Acc : 0.8000, Test Acc : 0.8800
# Epoch   57 : Loss : 0.2490, Acc : 0.8000, Test Acc : 0.8800
# Epoch   58 : Loss : 0.2465, Acc : 0.8000, Test Acc : 0.8800
# Epoch   59 : Loss : 0.2441, Acc : 0.8000, Test Acc : 0.8800
# Epoch   60 : Loss : 0.2418, Acc : 0.8000, Test Acc : 0.8800
# Epoch   61 : Loss : 0.2395, Acc : 0.8000, Test Acc : 0.8800
# Epoch   62 : Loss : 0.2372, Acc : 0.8000, Test Acc : 0.8800
# Epoch   63 : Loss : 0.2350, Acc : 0.8000, Test Acc : 0.8800
# Epoch   64 : Loss : 0.2328, Acc : 0.8000, Test Acc : 0.8800
# Epoch   65 : Loss : 0.2307, Acc : 0.8000, Test Acc : 0.8840
# Epoch   66 : Loss : 0.2286, Acc : 0.8000, Test Acc : 0.8840
# Epoch   67 : Loss : 0.2265, Acc : 0.8000, Test Acc : 0.8840
# Epoch   68 : Loss : 0.2245, Acc : 0.8000, Test Acc : 0.8880
# Epoch   69 : Loss : 0.2225, Acc : 0.8000, Test Acc : 0.8880
# Epoch   70 : Loss : 0.2205, Acc : 0.8000, Test Acc : 0.8920
# Epoch   71 : Loss : 0.2186, Acc : 0.8000, Test Acc : 0.9000
# Epoch   72 : Loss : 0.2168, Acc : 0.8000, Test Acc : 0.9040
# Epoch   73 : Loss : 0.2150, Acc : 0.8000, Test Acc : 0.9080
# Epoch   74 : Loss : 0.2132, Acc : 0.8000, Test Acc : 0.9080
# Epoch   75 : Loss : 0.2114, Acc : 0.8000, Test Acc : 0.9080
# Epoch   76 : Loss : 0.2097, Acc : 0.8000, Test Acc : 0.9080
# Epoch   77 : Loss : 0.2080, Acc : 0.8000, Test Acc : 0.9040
# Epoch   78 : Loss : 0.2067, Acc : 0.8000, Test Acc : 0.9080
# Epoch   79 : Loss : 0.2056, Acc : 0.8000, Test Acc : 0.9080
# Epoch   80 : Loss : 0.2045, Acc : 0.8000, Test Acc : 0.9080
# Epoch   81 : Loss : 0.2035, Acc : 0.8000, Test Acc : 0.9080
# Epoch   82 : Loss : 0.2024, Acc : 0.8000, Test Acc : 0.9040
# Epoch   83 : Loss : 0.2014, Acc : 0.8000, Test Acc : 0.9040
# Epoch   84 : Loss : 0.2003, Acc : 0.8000, Test Acc : 0.9040
# Epoch   85 : Loss : 0.1993, Acc : 0.8000, Test Acc : 0.9040
# Epoch   86 : Loss : 0.1983, Acc : 0.8000, Test Acc : 0.9040
# Epoch   87 : Loss : 0.1974, Acc : 0.8000, Test Acc : 0.9040
# Epoch   88 : Loss : 0.1964, Acc : 0.8000, Test Acc : 0.9040
# Epoch   89 : Loss : 0.1955, Acc : 0.8000, Test Acc : 0.9040
# Epoch   90 : Loss : 0.1946, Acc : 0.8000, Test Acc : 0.9040
# Epoch   91 : Loss : 0.1937, Acc : 0.8000, Test Acc : 0.9000
# Epoch   92 : Loss : 0.1929, Acc : 0.8000, Test Acc : 0.9000
# Epoch   93 : Loss : 0.1920, Acc : 0.8000, Test Acc : 0.9000
# Epoch   94 : Loss : 0.1912, Acc : 0.8000, Test Acc : 0.9000
# Epoch   95 : Loss : 0.1904, Acc : 0.8000, Test Acc : 0.9000
# Epoch   96 : Loss : 0.1896, Acc : 0.8000, Test Acc : 0.9000
# Epoch   97 : Loss : 0.1888, Acc : 0.8000, Test Acc : 0.8920
# Epoch   98 : Loss : 0.1880, Acc : 0.8000, Test Acc : 0.8920
# Epoch   99 : Loss : 0.1873, Acc : 0.8000, Test Acc : 0.8920
# Epoch  100 : Loss : 0.1865, Acc : 0.8000, Test Acc : 0.8880
# Epoch  101 : Loss : 0.1858, Acc : 0.8000, Test Acc : 0.8880
# Epoch  102 : Loss : 0.1851, Acc : 0.8000, Test Acc : 0.8880
# Epoch  103 : Loss : 0.1844, Acc : 0.9000, Test Acc : 0.8840
# Epoch  104 : Loss : 0.1838, Acc : 0.9000, Test Acc : 0.8840
# Epoch  105 : Loss : 0.1831, Acc : 0.9000, Test Acc : 0.8840
# Epoch  106 : Loss : 0.1824, Acc : 0.9000, Test Acc : 0.8840
# Epoch  107 : Loss : 0.1818, Acc : 0.9000, Test Acc : 0.8840
# Epoch  108 : Loss : 0.1812, Acc : 0.9000, Test Acc : 0.8840
# Epoch  109 : Loss : 0.1806, Acc : 0.9000, Test Acc : 0.8840
# Epoch  110 : Loss : 0.1800, Acc : 0.9000, Test Acc : 0.8840
# Epoch  111 : Loss : 0.1794, Acc : 0.9000, Test Acc : 0.8840
# Epoch  112 : Loss : 0.1789, Acc : 0.9000, Test Acc : 0.8800
# Epoch  113 : Loss : 0.1783, Acc : 0.9000, Test Acc : 0.8800
# Epoch  114 : Loss : 0.1778, Acc : 0.9000, Test Acc : 0.8800
# Epoch  115 : Loss : 0.1772, Acc : 0.9000, Test Acc : 0.8800
# Epoch  116 : Loss : 0.1767, Acc : 0.9000, Test Acc : 0.8800
# Epoch  117 : Loss : 0.1762, Acc : 0.9000, Test Acc : 0.8760
# Epoch  118 : Loss : 0.1757, Acc : 0.9000, Test Acc : 0.8760
# Epoch  119 : Loss : 0.1752, Acc : 0.9000, Test Acc : 0.8720
# Epoch  120 : Loss : 0.1747, Acc : 0.9000, Test Acc : 0.8640
# Epoch  121 : Loss : 0.1742, Acc : 0.9000, Test Acc : 0.8640
# Epoch  122 : Loss : 0.1738, Acc : 0.9000, Test Acc : 0.8640
# Epoch  123 : Loss : 0.1733, Acc : 0.9000, Test Acc : 0.8640
# Epoch  124 : Loss : 0.1729, Acc : 0.9000, Test Acc : 0.8640
# Epoch  125 : Loss : 0.1724, Acc : 0.9000, Test Acc : 0.8640
# Epoch  126 : Loss : 0.1720, Acc : 0.9000, Test Acc : 0.8640
# Epoch  127 : Loss : 0.1716, Acc : 0.9000, Test Acc : 0.8640
# Epoch  128 : Loss : 0.1711, Acc : 0.9000, Test Acc : 0.8640
# Epoch  129 : Loss : 0.1707, Acc : 0.9000, Test Acc : 0.8640
# Epoch  130 : Loss : 0.1704, Acc : 0.9000, Test Acc : 0.8640
# Epoch  131 : Loss : 0.1700, Acc : 0.9000, Test Acc : 0.8640
# Epoch  132 : Loss : 0.1696, Acc : 0.9000, Test Acc : 0.8640
# Epoch  133 : Loss : 0.1692, Acc : 0.9000, Test Acc : 0.8640
# Epoch  134 : Loss : 0.1688, Acc : 0.9000, Test Acc : 0.8640
# Epoch  135 : Loss : 0.1685, Acc : 0.9000, Test Acc : 0.8640
# Epoch  136 : Loss : 0.1681, Acc : 0.9000, Test Acc : 0.8640
# Epoch  137 : Loss : 0.1678, Acc : 0.9000, Test Acc : 0.8640
# Epoch  138 : Loss : 0.1674, Acc : 0.9000, Test Acc : 0.8640
# Epoch  139 : Loss : 0.1671, Acc : 0.9000, Test Acc : 0.8640
# Epoch  140 : Loss : 0.1667, Acc : 0.9000, Test Acc : 0.8640
# Epoch  141 : Loss : 0.1664, Acc : 0.9000, Test Acc : 0.8640
# Epoch  142 : Loss : 0.1660, Acc : 0.9000, Test Acc : 0.8640
# Epoch  143 : Loss : 0.1657, Acc : 0.9000, Test Acc : 0.8640
# Epoch  144 : Loss : 0.1654, Acc : 0.9000, Test Acc : 0.8640
# Epoch  145 : Loss : 0.1650, Acc : 0.9000, Test Acc : 0.8640
# Epoch  146 : Loss : 0.1647, Acc : 0.9000, Test Acc : 0.8640
# Epoch  147 : Loss : 0.1644, Acc : 0.9000, Test Acc : 0.8640
# Epoch  148 : Loss : 0.1641, Acc : 0.9000, Test Acc : 0.8640
# Epoch  149 : Loss : 0.1637, Acc : 0.9000, Test Acc : 0.8640

# %%
from mlxtend.plotting import plot_decision_regions

# Affichage des données
plt.plot(x_train_unlab[y_train_unlab==0,0], x_train_unlab[y_train_unlab==0,1], 'b.')
plt.plot(x_train_unlab[y_train_unlab==1,0], x_train_unlab[y_train_unlab==1,1], 'r.')

plt.plot(x_test[y_test==0,0], x_test[y_test==0,1], 'b+')
plt.plot(x_test[y_test==1,0], x_test[y_test==1,1], 'r+')

plt.plot(x_train_lab[y_train_lab==0,0], x_train_lab[y_train_lab==0,1], 'b.', markersize=30)
plt.plot(x_train_lab[y_train_lab==1,0], x_train_lab[y_train_lab==1,1], 'r.', markersize=30)

plt.show()

#Affichage de la frontière de décision
plot_decision_regions(x_train_unlab, y_train_unlab, clf=model, legend=2)
plt.show()
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 13s 1ms/step

# %% [markdown]
# # Minimisation de l'entropie

# %% [markdown]
# Nous allons dans cette partie implémenter l'algorithme de minimisation de l'entropie de prédiction du modèle sur les données non labellisées, conjointement à la minimisation de l'entropie croisée sur les données labellisées.
#
# Pour commencer, implémentez la fonction de coût qui calcule l'entropie $H$ des prédictions du réseau $\hat{y}$ :
# $$ H(\hat{y}) = - ∑_{i=1}^N \hat{y}_i log(\hat{y}_i) $$
#
# Pour les exemples simples des datasets des 2 clusters et des 2 lunes, il faut implémenter une entropie binaire ! (plus tard, sur MNIST, il faudra implémenter une version multi-classe de l'entropie)

# %%
import tensorflow as tf

# Calcul de l'entropie de y_pred
# A COMPLETER
def binary_entropy_loss(y_pred):
    eps = 1e-7
    tf.clip_by_value(y_pred, eps, 1-eps)
    return - tf.math.reduce_sum(tf.multiply(y_pred, tf.math.log(y_pred)) + tf.multiply(1-y_pred, tf.math.log(1-y_pred)))

# %%
a = [1.0,2.0]
b = [1.0,2.0]
print(tf.multiply(a,tf.math.log(b)))
print([1]+[3])
# Out:
# tf.Tensor([0.        1.3862944], shape=(2,), dtype=float32)
# [1, 3]

# %% [markdown]
# **ATTENTION: il faut gérer manuellement les cas où $\hat{y}$ vaudrait 0 ou 1, ce qui donnerait une valeur *NaN* à la fonction de coût.** Pour cela, vous pouvez utiliser la fonction [clip_by_value](https://www.tensorflow.org/api_docs/python/tf/clip_by_value) qui va vous permettre de circonscrire les valeurs de $\hat{y}$ à $[\epsilon , 1 - \epsilon ] $ (vous pouvez par exemple utiliser la valeur $\epsilon = 10^{-7}$).

# %% [markdown]
# **ATTENTION 2**: cette fonction de coût doit être dérivable et doit donc être implémentée uniquement en utilisant des fonctions de *Tensorflow* (et surtout pas *Numpy*)

# %% [markdown]
# **Travail à faire** : Reprenez maintenant la boucle d'apprentissage supervisé et introduisez la minimisation d'entropie pour régulariser l'apprentissage.
#
# La difficulté principale va être l'introduction des données non labellisées dans la boucle. Ainsi, un batch devra maintenant être composé de données labellisées et non labellisées. Je vous suggère de conserver le même nombre de données labellisées par batch que précédemment (i.e. 16) et de prendre un plus grand nombre de données non labellisées, par exemple 90.
#
# N'oubliez pas également d'introduire un hyperparamètre λ pour contrôler l'équilibre entre perte supervisée et non supervisée. Utilisez un λ constant dans un premier temps, et testez ensuite des variantes qui consisteraient à augmenter progressivement sa valeur au fil des epochs.
#
# La fonction objectif à minimiser aura donc la forme :
# $$  J = \sum_{(x,y) \in \mathcal{L}} CE(y, \hat{y}) + \lambda \sum_{x \in \mathcal{U}} H(\hat{y})	$$

# %% [markdown]
# Une fois cette étape réalisée, vous pouvez tester l'algorithme sur le dataset des 2 lunes ; comme annoncé en cours, vous devriez avoir beaucoup de mal à faire fonctionner l'algorithme sur ces données.
#
# S'il vous reste du temps, vous pouvez également tester votre algorithme sur les données MNIST, cela vous avancera pour la prochaine séance.

# %%
import tensorflow as tf
from tensorflow import keras
import math

# Données et modèle du problème des 2 lunes
x_train_lab, y_train_lab, x_train_unlab, y_train_unlab, x_test, y_test = generate_2moons_dataset(num_lab = 10, num_unlab=740, num_test=250)
model = create_model_2moons()

# Hyperparamètres de l'apprentissage
lambda_stp = 1e-3
epochs = 150
batch_size_labeled = 16
batch_size_unlabeled = 90
if batch_size < x_train_lab.shape[0]:
  steps_per_epoch = math.floor(x_train_lab.shape[0]/batch_size)
else:
  steps_per_epoch = 1
  batch_size = x_train_lab.shape[0]

# Instanciation d'un optimiseur et d'une fonction de coût.
optimizer = keras.optimizers.Adam(learning_rate=1e-2)
loss_fn = keras.losses.BinaryCrossentropy()

# Préparation des métriques pour le suivi de la performance du modèle.
train_acc_metric = keras.metrics.BinaryAccuracy()
test_acc_metric = keras.metrics.BinaryAccuracy()

# Indices de l'ensemble labellisé
indices = np.arange(x_train_lab.shape[0])
indices_unlab = np.arange(x_train_unlab.shape[0])

# Boucle sur les epochs
for epoch in range(epochs):

  # A chaque nouvelle epoch, on randomise les indices de l'ensemble labellisé
  np.random.shuffle(indices)

  # Et on recommence à cumuler la loss
  cum_loss_value = 0

  for step in range(steps_per_epoch):

    # Sélection des données du prochain batch
    x_batch = x_train_lab[indices[step*batch_size_labeled: (step+1)*batch_size_labeled]]
    x_batch_unlab = x_train_unlab[indices_unlab[step*batch_size_unlabeled: (step+1)*batch_size_unlabeled]]
    y_batch = y_train_lab[indices[step*batch_size_labeled: (step+1)*batch_size_labeled]]

    # Etape nécessaire pour comparer y_batch à la sortie du réseau
    y_batch = np.expand_dims(y_batch, 1)

    # Les opérations effectuées par le modèle dans ce bloc sont suivies et permettront
    # la différentiation automatique.
    with tf.GradientTape() as tape:

      # Application du réseau aux données d'entrée
      y_pred = model(x_batch, training=True)  # Logits for this minibatch
      y_pred_unlab = model(x_batch_unlab, training=True)

      # Calcul de la fonction de perte sur ce batch
      loss_value = loss_fn(y_batch, y_pred) + (step*lambda_stp)**2 * binary_entropy_loss(y_pred_unlab)

      # Calcul des gradients par différentiation automatique
      grads = tape.gradient(loss_value, model.trainable_weights)

      # Réalisation d'une itération de la descente de gradient (mise à jour des paramètres du réseau)
      optimizer.apply_gradients(zip(grads, model.trainable_weights))

      # Mise à jour de la métrique
      train_acc_metric.update_state(y_batch, y_pred)

      cum_loss_value = cum_loss_value + loss_value

  # Calcul de la précision à la fin de l'epoch
  train_acc = train_acc_metric.result()

  # Calcul de la précision sur l'ensemble de test à la fin de l'epoch
  test_logits = model(x_test, training=False)
  test_acc_metric.update_state(np.expand_dims(y_test, 1), test_logits)
  test_acc = test_acc_metric.result()

  print("Epoch %4d : Loss : %.4f, Acc : %.4f, Test Acc : %.4f" % (epoch, float(cum_loss_value/steps_per_epoch), float(train_acc), float(test_acc)))

  # Remise à zéro des métriques pour la prochaine epoch
  train_acc_metric.reset_state()
  test_acc_metric.reset_state()
# Out:
# Epoch    0 : Loss : 0.6268, Acc : 0.7000, Test Acc : 0.5120
# Epoch    1 : Loss : 0.6078, Acc : 0.7000, Test Acc : 0.5120
# Epoch    2 : Loss : 0.5897, Acc : 0.7000, Test Acc : 0.5120
# Epoch    3 : Loss : 0.5728, Acc : 0.7000, Test Acc : 0.5120
# Epoch    4 : Loss : 0.5572, Acc : 0.7000, Test Acc : 0.5120
# Epoch    5 : Loss : 0.5425, Acc : 0.7000, Test Acc : 0.5080
# Epoch    6 : Loss : 0.5289, Acc : 0.7000, Test Acc : 0.4920
# Epoch    7 : Loss : 0.5159, Acc : 0.7000, Test Acc : 0.4920
# Epoch    8 : Loss : 0.5034, Acc : 0.7000, Test Acc : 0.6000
# Epoch    9 : Loss : 0.4916, Acc : 0.7000, Test Acc : 0.6760
# Epoch   10 : Loss : 0.4803, Acc : 0.7000, Test Acc : 0.7200
# Epoch   11 : Loss : 0.4692, Acc : 0.9000, Test Acc : 0.7440
# Epoch   12 : Loss : 0.4582, Acc : 0.9000, Test Acc : 0.7520
# Epoch   13 : Loss : 0.4475, Acc : 0.9000, Test Acc : 0.7680
# Epoch   14 : Loss : 0.4372, Acc : 0.9000, Test Acc : 0.7840
# Epoch   15 : Loss : 0.4277, Acc : 0.9000, Test Acc : 0.7920
# Epoch   16 : Loss : 0.4187, Acc : 0.9000, Test Acc : 0.8040
# Epoch   17 : Loss : 0.4101, Acc : 0.9000, Test Acc : 0.8080
# Epoch   18 : Loss : 0.4019, Acc : 0.9000, Test Acc : 0.8080
# Epoch   19 : Loss : 0.3939, Acc : 0.9000, Test Acc : 0.8080
# Epoch   20 : Loss : 0.3862, Acc : 0.9000, Test Acc : 0.8080
# Epoch   21 : Loss : 0.3787, Acc : 0.9000, Test Acc : 0.8120
# Epoch   22 : Loss : 0.3722, Acc : 0.9000, Test Acc : 0.8120
# Epoch   23 : Loss : 0.3662, Acc : 0.8000, Test Acc : 0.8160
# Epoch   24 : Loss : 0.3604, Acc : 0.8000, Test Acc : 0.8160
# Epoch   25 : Loss : 0.3546, Acc : 0.8000, Test Acc : 0.8240
# Epoch   26 : Loss : 0.3490, Acc : 0.8000, Test Acc : 0.8280
# Epoch   27 : Loss : 0.3435, Acc : 0.8000, Test Acc : 0.8280
# Epoch   28 : Loss : 0.3381, Acc : 0.8000, Test Acc : 0.8320
# Epoch   29 : Loss : 0.3329, Acc : 0.8000, Test Acc : 0.8360
# Epoch   30 : Loss : 0.3277, Acc : 0.8000, Test Acc : 0.8440
# Epoch   31 : Loss : 0.3225, Acc : 0.8000, Test Acc : 0.8440
# Epoch   32 : Loss : 0.3174, Acc : 0.8000, Test Acc : 0.8440
# Epoch   33 : Loss : 0.3124, Acc : 0.8000, Test Acc : 0.8440
# Epoch   34 : Loss : 0.3075, Acc : 0.8000, Test Acc : 0.8440
# Epoch   35 : Loss : 0.3026, Acc : 0.8000, Test Acc : 0.8400
# Epoch   36 : Loss : 0.2978, Acc : 0.8000, Test Acc : 0.8440
# Epoch   37 : Loss : 0.2931, Acc : 0.8000, Test Acc : 0.8480
# Epoch   38 : Loss : 0.2884, Acc : 0.8000, Test Acc : 0.8520
# Epoch   39 : Loss : 0.2838, Acc : 0.8000, Test Acc : 0.8520
# Epoch   40 : Loss : 0.2792, Acc : 0.8000, Test Acc : 0.8560
# Epoch   41 : Loss : 0.2751, Acc : 0.8000, Test Acc : 0.8600
# Epoch   42 : Loss : 0.2710, Acc : 0.8000, Test Acc : 0.8640
# Epoch   43 : Loss : 0.2669, Acc : 0.8000, Test Acc : 0.8640
# Epoch   44 : Loss : 0.2629, Acc : 0.8000, Test Acc : 0.8680
# Epoch   45 : Loss : 0.2588, Acc : 0.8000, Test Acc : 0.8720
# Epoch   46 : Loss : 0.2548, Acc : 0.8000, Test Acc : 0.8840
# Epoch   47 : Loss : 0.2509, Acc : 0.8000, Test Acc : 0.8880
# Epoch   48 : Loss : 0.2474, Acc : 0.8000, Test Acc : 0.8880
# Epoch   49 : Loss : 0.2440, Acc : 0.8000, Test Acc : 0.8960
# Epoch   50 : Loss : 0.2406, Acc : 0.9000, Test Acc : 0.9000
# Epoch   51 : Loss : 0.2372, Acc : 0.9000, Test Acc : 0.9040
# Epoch   52 : Loss : 0.2339, Acc : 0.9000, Test Acc : 0.9040
# Epoch   53 : Loss : 0.2307, Acc : 0.9000, Test Acc : 0.9040
# Epoch   54 : Loss : 0.2275, Acc : 0.9000, Test Acc : 0.9040
# Epoch   55 : Loss : 0.2244, Acc : 0.9000, Test Acc : 0.9040
# Epoch   56 : Loss : 0.2214, Acc : 0.9000, Test Acc : 0.9000
# Epoch   57 : Loss : 0.2186, Acc : 0.9000, Test Acc : 0.9040
# Epoch   58 : Loss : 0.2158, Acc : 0.9000, Test Acc : 0.9080
# Epoch   59 : Loss : 0.2129, Acc : 0.9000, Test Acc : 0.9040
# Epoch   60 : Loss : 0.2103, Acc : 0.9000, Test Acc : 0.9040
# Epoch   61 : Loss : 0.2079, Acc : 0.9000, Test Acc : 0.9040
# Epoch   62 : Loss : 0.2055, Acc : 0.9000, Test Acc : 0.9040
# Epoch   63 : Loss : 0.2032, Acc : 0.9000, Test Acc : 0.9040
# Epoch   64 : Loss : 0.2008, Acc : 0.9000, Test Acc : 0.9040
# Epoch   65 : Loss : 0.1984, Acc : 0.9000, Test Acc : 0.9000
# Epoch   66 : Loss : 0.1962, Acc : 0.9000, Test Acc : 0.9000
# Epoch   67 : Loss : 0.1940, Acc : 0.9000, Test Acc : 0.9000
# Epoch   68 : Loss : 0.1918, Acc : 0.9000, Test Acc : 0.8960
# Epoch   69 : Loss : 0.1897, Acc : 0.9000, Test Acc : 0.8920
# Epoch   70 : Loss : 0.1876, Acc : 0.9000, Test Acc : 0.8880
# Epoch   71 : Loss : 0.1856, Acc : 0.9000, Test Acc : 0.8880
# Epoch   72 : Loss : 0.1840, Acc : 0.9000, Test Acc : 0.8840
# Epoch   73 : Loss : 0.1825, Acc : 0.9000, Test Acc : 0.8840
# Epoch   74 : Loss : 0.1811, Acc : 0.9000, Test Acc : 0.8880
# Epoch   75 : Loss : 0.1797, Acc : 0.9000, Test Acc : 0.8880
# Epoch   76 : Loss : 0.1784, Acc : 0.9000, Test Acc : 0.8880
# Epoch   77 : Loss : 0.1772, Acc : 0.9000, Test Acc : 0.8880
# Epoch   78 : Loss : 0.1759, Acc : 0.9000, Test Acc : 0.8880
# Epoch   79 : Loss : 0.1746, Acc : 0.9000, Test Acc : 0.8880
# Epoch   80 : Loss : 0.1734, Acc : 0.9000, Test Acc : 0.8880
# Epoch   81 : Loss : 0.1721, Acc : 0.9000, Test Acc : 0.8840
# Epoch   82 : Loss : 0.1708, Acc : 0.9000, Test Acc : 0.8840
# Epoch   83 : Loss : 0.1697, Acc : 0.9000, Test Acc : 0.8800
# Epoch   84 : Loss : 0.1685, Acc : 0.9000, Test Acc : 0.8800
# Epoch   85 : Loss : 0.1675, Acc : 0.9000, Test Acc : 0.8800
# Epoch   86 : Loss : 0.1664, Acc : 0.9000, Test Acc : 0.8680
# Epoch   87 : Loss : 0.1653, Acc : 0.9000, Test Acc : 0.8680
# Epoch   88 : Loss : 0.1641, Acc : 0.9000, Test Acc : 0.8680
# Epoch   89 : Loss : 0.1631, Acc : 0.9000, Test Acc : 0.8680
# Epoch   90 : Loss : 0.1621, Acc : 0.9000, Test Acc : 0.8680
# Epoch   91 : Loss : 0.1611, Acc : 0.9000, Test Acc : 0.8640
# Epoch   92 : Loss : 0.1600, Acc : 0.9000, Test Acc : 0.8640
# Epoch   93 : Loss : 0.1589, Acc : 0.9000, Test Acc : 0.8640
# Epoch   94 : Loss : 0.1580, Acc : 0.9000, Test Acc : 0.8720
# Epoch   95 : Loss : 0.1570, Acc : 0.9000, Test Acc : 0.8720
# Epoch   96 : Loss : 0.1560, Acc : 0.9000, Test Acc : 0.8720
# Epoch   97 : Loss : 0.1550, Acc : 0.9000, Test Acc : 0.8720
# Epoch   98 : Loss : 0.1542, Acc : 0.9000, Test Acc : 0.8720
# Epoch   99 : Loss : 0.1532, Acc : 0.9000, Test Acc : 0.8720
# Epoch  100 : Loss : 0.1523, Acc : 0.9000, Test Acc : 0.8720
# Epoch  101 : Loss : 0.1513, Acc : 0.9000, Test Acc : 0.8720
# Epoch  102 : Loss : 0.1505, Acc : 0.9000, Test Acc : 0.8720
# Epoch  103 : Loss : 0.1496, Acc : 0.9000, Test Acc : 0.8680
# Epoch  104 : Loss : 0.1486, Acc : 0.9000, Test Acc : 0.8680
# Epoch  105 : Loss : 0.1478, Acc : 0.9000, Test Acc : 0.8680
# Epoch  106 : Loss : 0.1470, Acc : 0.9000, Test Acc : 0.8680
# Epoch  107 : Loss : 0.1461, Acc : 0.9000, Test Acc : 0.8680
# Epoch  108 : Loss : 0.1452, Acc : 0.9000, Test Acc : 0.8680
# Epoch  109 : Loss : 0.1444, Acc : 0.9000, Test Acc : 0.8680
# Epoch  110 : Loss : 0.1436, Acc : 0.9000, Test Acc : 0.8680
# Epoch  111 : Loss : 0.1427, Acc : 0.9000, Test Acc : 0.8640
# Epoch  112 : Loss : 0.1418, Acc : 0.9000, Test Acc : 0.8640
# Epoch  113 : Loss : 0.1409, Acc : 0.9000, Test Acc : 0.8640
# Epoch  114 : Loss : 0.1401, Acc : 0.9000, Test Acc : 0.8640
# Epoch  115 : Loss : 0.1392, Acc : 0.9000, Test Acc : 0.8640
# Epoch  116 : Loss : 0.1384, Acc : 0.9000, Test Acc : 0.8640
# Epoch  117 : Loss : 0.1375, Acc : 0.9000, Test Acc : 0.8640
# Epoch  118 : Loss : 0.1366, Acc : 0.9000, Test Acc : 0.8640
# Epoch  119 : Loss : 0.1358, Acc : 0.9000, Test Acc : 0.8640
# Epoch  120 : Loss : 0.1350, Acc : 0.9000, Test Acc : 0.8640
# Epoch  121 : Loss : 0.1341, Acc : 1.0000, Test Acc : 0.8600
# Epoch  122 : Loss : 0.1333, Acc : 1.0000, Test Acc : 0.8600
# Epoch  123 : Loss : 0.1324, Acc : 1.0000, Test Acc : 0.8600
# Epoch  124 : Loss : 0.1316, Acc : 1.0000, Test Acc : 0.8600
# Epoch  125 : Loss : 0.1308, Acc : 1.0000, Test Acc : 0.8600
# Epoch  126 : Loss : 0.1300, Acc : 1.0000, Test Acc : 0.8600
# Epoch  127 : Loss : 0.1292, Acc : 1.0000, Test Acc : 0.8600
# Epoch  128 : Loss : 0.1282, Acc : 1.0000, Test Acc : 0.8600
# Epoch  129 : Loss : 0.1275, Acc : 1.0000, Test Acc : 0.8600
# Epoch  130 : Loss : 0.1267, Acc : 1.0000, Test Acc : 0.8600
# Epoch  131 : Loss : 0.1258, Acc : 1.0000, Test Acc : 0.8560
# Epoch  132 : Loss : 0.1249, Acc : 1.0000, Test Acc : 0.8520
# Epoch  133 : Loss : 0.1239, Acc : 1.0000, Test Acc : 0.8480
# Epoch  134 : Loss : 0.1231, Acc : 1.0000, Test Acc : 0.8480
# Epoch  135 : Loss : 0.1223, Acc : 1.0000, Test Acc : 0.8480
# Epoch  136 : Loss : 0.1214, Acc : 1.0000, Test Acc : 0.8480
# Epoch  137 : Loss : 0.1205, Acc : 1.0000, Test Acc : 0.8480
# Epoch  138 : Loss : 0.1197, Acc : 1.0000, Test Acc : 0.8480
# Epoch  139 : Loss : 0.1188, Acc : 1.0000, Test Acc : 0.8520
# Epoch  140 : Loss : 0.1180, Acc : 1.0000, Test Acc : 0.8520
# Epoch  141 : Loss : 0.1171, Acc : 1.0000, Test Acc : 0.8520
# Epoch  142 : Loss : 0.1162, Acc : 1.0000, Test Acc : 0.8480
# Epoch  143 : Loss : 0.1153, Acc : 1.0000, Test Acc : 0.8480
# Epoch  144 : Loss : 0.1145, Acc : 1.0000, Test Acc : 0.8480
# Epoch  145 : Loss : 0.1136, Acc : 1.0000, Test Acc : 0.8440
# Epoch  146 : Loss : 0.1127, Acc : 1.0000, Test Acc : 0.8440
# Epoch  147 : Loss : 0.1118, Acc : 1.0000, Test Acc : 0.8440
# Epoch  148 : Loss : 0.1110, Acc : 1.0000, Test Acc : 0.8440
# Epoch  149 : Loss : 0.1101, Acc : 1.0000, Test Acc : 0.8440

# %%
from mlxtend.plotting import plot_decision_regions

# Affichage des données
plt.plot(x_train_unlab[y_train_unlab==0,0], x_train_unlab[y_train_unlab==0,1], 'b.')
plt.plot(x_train_unlab[y_train_unlab==1,0], x_train_unlab[y_train_unlab==1,1], 'r.')

plt.plot(x_test[y_test==0,0], x_test[y_test==0,1], 'b+')
plt.plot(x_test[y_test==1,0], x_test[y_test==1,1], 'r+')

plt.plot(x_train_lab[y_train_lab==0,0], x_train_lab[y_train_lab==0,1], 'b.', markersize=30)
plt.plot(x_train_lab[y_train_lab==1,0], x_train_lab[y_train_lab==1,1], 'r.', markersize=30)

plt.show()

#Affichage de la frontière de décision
plot_decision_regions(x_train_unlab, y_train_unlab, clf=model, legend=2)
plt.show()
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 12s 1ms/step

# %% [markdown]
# # MNIST

# %% [markdown]
# ## Chargement des données

# %%
from tensorflow.keras.datasets import mnist
import numpy as np
from sklearn.model_selection import train_test_split

def generate_mnist_dataset(num_lab = 10):

  # Chargement et normalisation (entre 0 et 1) des données de la base de données MNIST
  (x_train, y_train), (x_test, y_test) = mnist.load_data()

  x_train = np.expand_dims(x_train.astype('float32') / 255., 3)
  x_test = np.expand_dims(x_test.astype('float32') / 255., 3)

  x_train_lab, x_train_unlab, y_train_lab, y_train_unlab = train_test_split(x_train, y_train, test_size=(x_train.shape[0]-num_lab)/x_train.shape[0], random_state=2)

  return x_train_lab, y_train_lab, x_train_unlab, y_train_unlab, x_test, y_test

# %%
x_train_lab, y_train_lab, x_train_unlab, y_train_unlab, x_test, y_test = generate_mnist_dataset(num_lab = 10)

print(x_train_lab.shape, x_train_unlab.shape, x_test.shape)
print(y_train_lab.shape, y_train_unlab.shape, y_test.shape)

# %% [markdown]
# ## Définition du modèle

# %%
# A COMPLETER
# Ici, on implémentera le modèle LeNet-5 :
# 1 couche de convolution 5x5 à 6 filtres suivie d'un max pooling
# puis 1 couche de convolution 5x5 à 16 filtres suivie d'un max pooling et d'un Flatten
# Enfin 2 couches denses de 120 et 84 neurones, avant la couche de sortie à 10 neurones.
def create_model_mnist():

  inputs = keras.Input(shape=(...))


  outputs = ...

  model = keras.Model(inputs=inputs, outputs=outputs)

  return model
